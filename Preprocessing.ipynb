# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

from sklearn import preprocessing

# %matplotlib inline

# %%
data = pd.read_csv('data/all_models_data.csv')
data.sample(5)
# Out:
#                   city    brand    model  \
# 2144   sankt-peterburg      kia     ceed
# 5214       novosibirsk  hyundai  solaris
# 1447             kazan    skoda  octavia
# 7762  nizhniy_novgorod  hyundai  solaris
# 4680            moskva    skoda  octavia
#
#                                                    href        price  year  \
# 2144  https://auto.ru/cars/used/sale/kia/ceed/109926...    280 000 ₽  2008
# 5214  https://auto.ru/cars/used/sale/hyundai/solaris...    525 000 ₽  2014
# 1447  https://auto.ru/cars/used/sale/skoda/octavia/1...    780 000 ₽  2015
# 7762  https://auto.ru/cars/used/sale/hyundai/solaris...    355 000 ₽  2011
# 4680  https://auto.ru/cars/used/sale/skoda/octavia/1...  1 095 000 ₽  2018
#
#          mileage        body_type       colour                engine_info  \
# 2144  225 000 км  универсал 5 дв.  серебристый  1.6 л / 122 л.с. / Бензин
# 5214  174 613 км            седан       чёрный  1.6 л / 123 л.с. / Бензин
# 1447  143 000 км          лифтбек        белый  1.6 л / 110 л.с. / Бензин
# 7762  115 250 км            седан        белый  1.4 л / 107 л.с. / Бензин
# 4680   20 894 км          лифтбек  серебристый  1.6 л / 110 л.с. / Бензин
#
#      annual_car_tax    transmission     drive hand_drive           condition  \
# 2144  4 270 ₽ / год  автоматическая  передний      Левый  Не требует ремонта
# 5214  1 230 ₽ / год  автоматическая  передний      Левый  Не требует ремонта
# 1447  3 080 ₽ / год    механическая  передний      Левый  Не требует ремонта
# 7762  2 140 ₽ / год    механическая  передний      Левый  Не требует ремонта
# 4680  2 750 ₽ / год  автоматическая  передний      Левый  Не требует ремонта
#
#        owners_num doc_unique
# 2144  3 или более   Оригинал
# 5214  3 или более   Оригинал
# 1447  2 владельца   Оригинал
# 7762  2 владельца   Дубликат
# 4680   1 владелец   Оригинал

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8245 entries, 0 to 8244
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            8245 non-null   object
#  1   brand           8245 non-null   object
#  2   model           8245 non-null   object
#  3   href            8245 non-null   object
#  4   price           8245 non-null   object
#  5   year            8245 non-null   int64
#  6   mileage         8245 non-null   object
#  7   body_type       8245 non-null   object
#  8   colour          8245 non-null   object
#  9   engine_info     8245 non-null   object
#  10  annual_car_tax  8245 non-null   object
#  11  transmission    8245 non-null   object
#  12  drive           8245 non-null   object
#  13  hand_drive      8245 non-null   object
#  14  condition       8245 non-null   object
#  15  owners_num      8245 non-null   object
#  16  doc_unique      8245 non-null   object
# dtypes: int64(1), object(16)
# memory usage: 1.1+ MB

# %% [markdown]
# # Cleaning data
# ## Numeric features
# ### Price

# %%
def clean_column(row):
    return float("".join(row.split()[:-1]))

# %%
clean_data = data.copy()
clean_data['price'] = clean_data[['price']].apply(lambda row: clean_column(row['price']), axis=1)

clean_data.sample(3)
# Out:
#                   city       brand    model  \
# 6693      ekaterinburg  volkswagen     polo
# 7965  nizhniy_novgorod  volkswagen     polo
# 4103            moskva     hyundai  solaris
#
#                                                    href     price  year  \
# 6693  https://auto.ru/cars/used/sale/volkswagen/polo...  210000.0  2002
# 7965  https://auto.ru/cars/used/sale/volkswagen/polo...  715000.0  2018
# 4103  https://auto.ru/cars/used/sale/hyundai/solaris...  500000.0  2014
#
#          mileage      body_type       colour                engine_info  \
# 6693  240 000 км  хэтчбек 5 дв.        белый   1.4 л / 75 л.с. / Бензин
# 7965   30 000 км          седан       чёрный  1.6 л / 110 л.с. / Бензин
# 4103   83 000 км  хэтчбек 5 дв.  серебристый  1.4 л / 107 л.с. / Бензин
#
#      annual_car_tax    transmission     drive hand_drive           condition  \
# 6693    188 ₽ / год  автоматическая  передний      Левый  Не требует ремонта
# 7965  3 465 ₽ / год    механическая  передний      Левый  Не требует ремонта
# 4103  2 675 ₽ / год  автоматическая  передний      Левый  Не требует ремонта
#
#        owners_num doc_unique
# 6693  3 или более   Оригинал
# 7965   1 владелец   Оригинал
# 4103  2 владельца   Оригинал

# %% [markdown]
# ### Mileage

# %%
def clean_mileage(mileage):
    return clean_column(mileage)

# %%
clean_data['mileage'] = clean_data[['mileage']].apply(lambda row: clean_mileage(row['mileage']), axis=1)
clean_data.sample(3)
# Out:
#               city    brand    model  \
# 720          kazan  hyundai  solaris
# 3343        moskva      kia      rio
# 5725  ekaterinburg      kia      rio
#
#                                                    href     price  year  \
# 720   https://auto.ru/cars/used/sale/hyundai/solaris...  310000.0  2012
# 3343  https://auto.ru/cars/used/sale/kia/rio/1099995...  545000.0  2013
# 5725  https://auto.ru/cars/used/sale/kia/rio/1096459...  444000.0  2012
#
#        mileage body_type      colour  \
# 720   132800.0     седан  золотистый
# 3343   90500.0     седан       серый
# 5725  184000.0     седан       белый
#
#                                             engine_info annual_car_tax  \
# 720   1.4 л / 107 л.с. / Бензин, газобаллонное обору...  2 568 ₽ / год
# 3343                          1.4 л / 107 л.с. / Бензин  2 675 ₽ / год
# 5725                          1.6 л / 123 л.с. / Бензин  1 648 ₽ / год
#
#         transmission     drive hand_drive           condition   owners_num  \
# 720     механическая  передний      Левый  Не требует ремонта  3 или более
# 3343  автоматическая  передний      Левый  Не требует ремонта   1 владелец
# 5725    механическая  передний      Левый  Не требует ремонта  3 или более
#
#      doc_unique
# 720    Дубликат
# 3343   Оригинал
# 5725   Оригинал

# %% [markdown]
# ### Owners num

# %%
clean_data['owners_num'].unique()
# Out:
# array(['2 владельца', '1 владелец', '3 или более', 'Оригинал'],
#       dtype=object)

# %%
print('Count wrong rows =', len(clean_data[clean_data['owners_num']=='Оригинал'].index))
# Out:
# Count wrong rows = 3

# %%
# Drop columns with wrong index
indexes = list(clean_data[clean_data['owners_num']=='Оригинал'].index)
clean_data = clean_data.drop(indexes, axis=0)

clean_data['owners_num'].unique()
# Out:
# array(['2 владельца', '1 владелец', '3 или более'], dtype=object)

# %%
owners_map = {'2 владельца':2, '1 владелец':1, '3 или более':3}

clean_data['owners_num'] = clean_data['owners_num'].map(owners_map)
clean_data.sample(3)
# Out:
#                   city       brand    model  \
# 452              kazan         kia     ceed
# 7964  nizhniy_novgorod  volkswagen     polo
# 980              kazan     hyundai  solaris
#
#                                                    href     price  year  \
# 452   https://auto.ru/cars/used/sale/kia/ceed/109459...  810000.0  2017
# 7964  https://auto.ru/cars/used/sale/volkswagen/polo...  170000.0  2002
# 980   https://auto.ru/cars/used/sale/hyundai/solaris...  389000.0  2012
#
#        mileage      body_type      colour                engine_info  \
# 452    43975.0  хэтчбек 5 дв.       белый  1.6 л / 130 л.с. / Бензин
# 7964  340000.0  хэтчбек 5 дв.       синий   1.2 л / 64 л.с. / Бензин
# 980   160000.0          седан  фиолетовый  1.4 л / 107 л.с. / Бензин
#
#      annual_car_tax  transmission     drive hand_drive           condition  \
# 452   4 290 ₽ / год  механическая  передний      Левый  Не требует ремонта
# 7964  1 440 ₽ / год  механическая  передний     Правый  Не требует ремонта
# 980   2 996 ₽ / год  механическая  передний      Левый  Не требует ремонта
#
#       owners_num doc_unique
# 452            1   Оригинал
# 7964           3   Оригинал
# 980            2   Оригинал

# %% [markdown]
# ### Annual car tax

# %%
def clean_car_tax(tax):
    tax = tax.split('/')[0]
    return clean_column(tax)

# %%
clean_data['annual_car_tax'] = clean_data[['annual_car_tax']].apply(lambda row: 
                                                                     clean_car_tax(row['annual_car_tax']), axis=1)
clean_data.sample(3)
# Out:
#                  city    brand    model  \
# 2945  sankt-peterburg    skoda  octavia
# 6350     ekaterinburg  hyundai  solaris
# 6092     ekaterinburg      kia     ceed
#
#                                                    href     price  year  \
# 2945  https://auto.ru/cars/used/sale/skoda/octavia/1...  590000.0  2013
# 6350  https://auto.ru/cars/used/sale/hyundai/solaris...  599000.0  2015
# 6092  https://auto.ru/cars/used/sale/kia/ceed/109814...  415000.0  2011
#
#        mileage      body_type       colour                engine_info  \
# 2945  144700.0        лифтбек        белый  1.8 л / 180 л.с. / Бензин
# 6350   92301.0  хэтчбек 5 дв.        белый  1.6 л / 123 л.с. / Бензин
# 6092  166000.0  хэтчбек 5 дв.  серебристый  1.6 л / 125 л.с. / Бензин
#
#       annual_car_tax      transmission     drive hand_drive  \
# 2945          9000.0  роботизированная  передний      Левый
# 6350          1156.0    автоматическая  передний      Левый
# 6092          1175.0      механическая  передний      Левый
#
#                condition  owners_num doc_unique
# 2945  Не требует ремонта           3   Оригинал
# 6350  Не требует ремонта           1   Оригинал
# 6092  Не требует ремонта           3   Дубликат

# %% [markdown]
# ### Engine info

# %%
def clean_engine_info(row, column_name):
    row = row.split('/')
    
    if column_name == 'volume':
        return float(row[0].split(' ')[0])
    elif column_name == 'horsepower':
        return float(row[1].split(' ')[1])
    else:
        return row[2].split(' ')[1]

# %%
# %%time

clean_data['engine_type'] = clean_data[['engine_info']].apply(lambda row: 
                                                              clean_engine_info(row['engine_info'], 'engine_type'), axis=1)
clean_data['volume'] = clean_data[['engine_info']].apply(lambda row: 
                                                              clean_engine_info(row['engine_info'], 'volume'), axis=1)
clean_data['horsepower'] = clean_data[['engine_info']].apply(lambda row: 
                                                              clean_engine_info(row['engine_info'], 'horsepower'), axis=1)
# Out:
# Wall time: 1.21 s

# %%
# Drop useless columns

clean_data = clean_data.drop(['engine_info', 'href'], axis=1)
clean_data.sample(3)
# Out:
#                   city       brand model     price  year   mileage body_type  \
# 5976      ekaterinburg         kia   rio  979000.0  2019   15630.0     седан
# 2614   sankt-peterburg  volkswagen  polo  345000.0  2013  192000.0     седан
# 7363  nizhniy_novgorod         kia   rio  569990.0  2017  122048.0     седан
#
#           colour  annual_car_tax    transmission     drive hand_drive  \
# 5976       серый          1156.0  автоматическая  передний      Левый
# 2614      чёрный          3675.0    механическая  передний      Левый
# 7363  коричневый          3875.0    механическая  передний      Левый
#
#                condition  owners_num doc_unique engine_type  volume  \
# 5976  Не требует ремонта           1   Оригинал      Бензин     1.6
# 2614  Не требует ремонта           2   Оригинал     Бензин,     1.6
# 7363  Не требует ремонта           1   Оригинал      Бензин     1.6
#
#       horsepower
# 5976       123.0
# 2614       105.0
# 7363       123.0

# %% [markdown]
# ## Categorical features

# %%
# Lets check unique values
for col in clean_data.columns:
    if clean_data[col].dtype == object:
        print(col, clean_data[col].unique())
# Out:
# city ['kazan' 'sankt-peterburg' 'moskva' 'novosibirsk' 'ekaterinburg'
#  'nizhniy_novgorod']
# brand ['kia' 'hyundai' 'volkswagen' 'skoda']
# model ['rio' 'ceed' 'solaris' 'polo' 'octavia']
# body_type ['седан' 'хэтчбек 5 дв.' 'универсал 5 дв.' 'хэтчбек 3 дв.' 'лифтбек']
# colour ['серебристый' 'чёрный' 'белый' 'серый' 'коричневый' 'красный'
#  'золотистый' 'зелёный' 'синий' 'фиолетовый' 'бежевый' 'оранжевый'
#  'голубой' 'жёлтый' 'пурпурный']
# transmission ['механическая' 'автоматическая' 'роботизированная']
# drive ['передний' 'полный']
# hand_drive ['Левый' 'Правый']
# condition ['Не требует ремонта']
# doc_unique ['Оригинал' 'Дубликат' 'Растаможен']
# engine_type ['Бензин' 'Бензин,' 'Дизель']

# %%
# Firstly, drop condition column, because it has only one point.
clean_data = clean_data.drop(['condition'], axis=1)

# %%
# Secondly, lets check Бензин, values in engine type
clean_data['engine_type'].unique()
# Out:
# array(['Бензин', 'Бензин,', 'Дизель'], dtype=object)

# %%
len(clean_data[clean_data['engine_type']=='Бензин,'])
# Out:
# 89

# %%
clean_data['engine_type'] = clean_data['engine_type'].replace('Бензин,', 'Бензин')
clean_data.sample(3)
# Out:
#                   city  brand    model     price  year   mileage body_type  \
# 1669             kazan  skoda  octavia  420000.0  2008  183000.0   лифтбек
# 6                kazan    kia      rio  730000.0  2017   93000.0     седан
# 7193  nizhniy_novgorod    kia      rio  645000.0  2016   52000.0     седан
#
#            colour  annual_car_tax    transmission     drive hand_drive  \
# 1669  серебристый          6880.0    механическая  передний      Левый
# 6           белый          4305.0  автоматическая  передний      Левый
# 7193        белый          3444.0  автоматическая  передний      Левый
#
#       owners_num doc_unique engine_type  volume  horsepower
# 1669           3   Оригинал      Бензин     1.8       160.0
# 6              1   Оригинал      Бензин     1.6       123.0
# 7193           3   Оригинал      Бензин     1.6       123.0

# %%
clean_data.to_csv('data/clean_data.csv', index=False)

# %% [markdown]
# # One hot encoding

# %%
encoded_data = pd.get_dummies(clean_data, prefix_sep='_', drop_first=True)
encoded_data.sample(3)
# Out:
#          price  year  mileage  annual_car_tax  owners_num  volume  horsepower  \
# 4510  595000.0  2014  59500.0          2625.0           1     1.6       105.0
# 4237  650000.0  2017  55000.0          3300.0           3     1.6       110.0
# 3162  770000.0  2018  90000.0          1200.0           1     1.4       100.0
#
#       city_kazan  city_moskva  city_nizhniy_novgorod  ...  colour_синий  \
# 4510           0            1                      0  ...             0
# 4237           0            1                      0  ...             0
# 3162           0            1                      0  ...             0
#
#       colour_фиолетовый  colour_чёрный  transmission_механическая  \
# 4510                  0              0                          0
# 4237                  0              0                          1
# 3162                  0              0                          1
#
#       transmission_роботизированная  drive_полный  hand_drive_Правый  \
# 4510                              0             0                  0
# 4237                              0             0                  0
# 3162                              0             0                  0
#
#       doc_unique_Оригинал  doc_unique_Растаможен  engine_type_Дизель
# 4510                    1                      0                   0
# 4237                    1                      0                   0
# 3162                    1                      0                   0
#
# [3 rows x 44 columns]

# %%
encoded_data.to_csv('data/encoded_data.csv', index=False)
